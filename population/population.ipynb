# %%
import tabula
import pandas as pd

# %%
dfs_108 = tabula.read_pdf("108人口.pdf", pages=1)
df_108 = dfs_108[0]
df_108 = df_108.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_108", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_108 = df_108.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_108 = df_108.drop([0, 1], axis=0)

df_108 = pd.read_excel("df_108.xlsx")
for i in df_108["total pepple_108"]:
    print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
dfs_107 = tabula.read_pdf("107人口.pdf", pages=1)

# %%
dfs_107 = tabula.read_pdf("107人口.pdf", pages=1)
df_107 = dfs_107[0]
df_107 = df_107.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_107", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_107 = df_107.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_107 = df_107.drop([0, 1], axis=0)
df_107
# Out:
#    village total pepple_107
# 2      正守里            3,320
# 3      正義里            5,363
# 4      正得里            3,721
# 5      民安里            4,647
# 6      康樂里            2,629
# 7      中山里            6,858
# 8      聚盛里            4,300
# 9      集英里            7,484
# 10     聚葉里            4,068
# 11     恆安里            4,994
# 12     晴光里            5,597
# 13     圓山里            4,399
# 14     劍潭里            3,859
# 15     大直里            9,735
# 16     成功里            7,235
# 17     永安里            9,929
# 18     大佳里            1,114
# 19     新喜里            5,503
# 20     新庄里            5,178
# 21     新福里            5,326
# 22     松江里            6,709
# 23     新生里            5,028
# 24     中庄里            5,235
# 25     行政里            7,596
# 26     行仁里            8,447
# 27     行孝里            4,235
# 28     下埤里            7,680
# 29     江寧里            7,176
# 30     江山里            7,751
# 31     中吉里            5,883
# 32     中原里            5,235
# 33     興亞里            5,453
# ...

# %%
dfs_106 = tabula.read_pdf("106人口.pdf", pages=1)
df_106 = dfs_106[0]
df_106 = df_106.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_106", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_106 = df_106.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_106 = df_106.drop([0, 1], axis=0)
df_106
# Out:
#    village total pepple_106
# 2      正守里            3,263
# 3      正義里            5,389
# 4      正得里            3,754
# 5      民安里            4,692
# 6      康樂里            2,622
# 7      中山里            6,773
# 8      聚盛里            4,244
# 9      集英里            7,390
# 10     聚葉里            4,076
# 11     恆安里            5,045
# 12     晴光里            5,572
# 13     圓山里            4,387
# 14     劍潭里            3,917
# 15     大直里            9,878
# 16     成功里            7,193
# 17     永安里            9,999
# 18     大佳里            1,147
# 19     新喜里            5,580
# 20     新庄里            5,204
# 21     新福里            5,334
# 22     松江里            6,777
# 23     新生里            5,059
# 24     中庄里            5,286
# 25     行政里            7,697
# 26     行仁里            8,524
# 27     行孝里            4,258
# 28     下埤里            7,777
# 29     江寧里            7,233
# 30     江山里            7,807
# 31     中吉里            5,879
# 32     中原里            5,208
# 33     興亞里            5,427
# ...

# %%
dfs_105 = tabula.read_pdf("105人口.pdf", pages=1)
df_105 = dfs_105[0]
df_105
df_105 = df_105.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_105", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_105 = df_105.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_105 = df_105.drop([0, 1], axis=0)
df_105
# Out:
#    village total pepple_105
# 2      正守里            3,277
# 3      正義里            5,406
# 4      正得里            3,812
# 5      民安里            4,735
# 6      康樂里            2,696
# 7      中山里            6,594
# 8      聚盛里            4,267
# 9      集英里            7,446
# 10     聚葉里            4,077
# 11     恆安里            5,046
# 12     晴光里            5,428
# 13     圓山里            4,413
# 14     劍潭里            3,922
# 15     大直里            9,994
# 16     成功里            7,205
# 17     永安里            9,991
# 18     大佳里            1,130
# 19     新喜里            5,588
# 20     新庄里            5,300
# 21     新福里            5,379
# 22     松江里            6,901
# 23     新生里            5,092
# 24     中庄里            5,305
# 25     行政里            7,716
# 26     行仁里            8,602
# 27     行孝里            4,301
# 28     下埤里            7,785
# 29     江寧里            7,228
# 30     江山里            7,817
# 31     中吉里            5,884
# 32     中原里            5,225
# 33     興亞里            5,437
# ...

# %%
dfs_104 = tabula.read_pdf("104人口.pdf", pages=1)
df_104 = dfs_104[0]
df_104 = df_104.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_104", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_104 = df_104.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_104 = df_104.drop([0, 1], axis=0)
df_104
# Out:
#    village total pepple_104
# 2      正守里            3,301
# 3      正義里            5,393
# 4      正得里            3,798
# 5      民安里            4,781
# 6      康樂里            2,706
# 7      中山里            6,490
# 8      聚盛里            4,258
# 9      集英里            7,451
# 10     聚葉里            4,035
# 11     恆安里            4,920
# 12     晴光里            5,403
# 13     圓山里            4,428
# 14     劍潭里            3,928
# 15     大直里           10,203
# 16     成功里            7,140
# 17     永安里           10,043
# 18     大佳里            1,131
# 19     新喜里            5,603
# 20     新庄里            5,264
# 21     新福里            5,298
# 22     松江里            6,970
# 23     新生里            5,177
# 24     中庄里            5,297
# 25     行政里            7,731
# 26     行仁里            8,527
# 27     行孝里            4,272
# 28     下埤里            7,818
# 29     江寧里            7,155
# 30     江山里            7,855
# 31     中吉里            5,888
# 32     中原里            5,229
# 33     興亞里            5,419
# ...

# %%
dfs_103 = tabula.read_pdf("101-104人口.pdf", pages=104)
df_103 = dfs_103[0]
df_103 = df_103.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_103", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_103 = df_103.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_103 = df_103.drop([0, 1], axis=0)
df_103
# Out:
#    village total pepple_103
# 2      正守里            3,300
# 3      正義里            5,368
# 4      正得里            3,789
# 5      民安里            4,841
# 6      康樂里            2,684
# 7      中山里            6,424
# 8      聚盛里            4,236
# 9      集英里            7,454
# 10     聚葉里            3,980
# 11     恆安里            4,834
# 12     晴光里            5,432
# 13     圓山里            4,451
# 14     劍潭里            3,899
# 15     大直里           10,316
# 16     成功里            7,102
# 17     永安里           10,081
# 18     大佳里            1,135
# 19     新喜里            5,564
# 20     新庄里            5,231
# 21     新福里            5,233
# 22     松江里            6,959
# 23     新生里            5,175
# 24     中庄里            5,251
# 25     行政里            7,730
# 26     行仁里            8,484
# 27     行孝里            4,198
# 28     下埤里            7,888
# 29     江寧里            7,120
# 30     江山里            7,832
# 31     中吉里            5,831
# 32     中原里            5,128
# 33     興亞里            5,404
# ...

# %%
dfs_102 = tabula.read_pdf("101-104人口.pdf", pages=102)
df_102 = dfs_102[0]
df_102 = df_102.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_102", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_102 = df_102.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_102 = df_102.drop([0, 1], axis=0)
df_102
# Out:
#    village total pepple_102
# 2      力行里            5,950
# 3      下埤里            7,837
# 4      大佳里            1,132
# 5      大直里           10,319
# 6      中山里            6,264
# 7      中央里            3,868
# 8      中吉里            5,846
# 9      中原里            5,097
# 10     中庄里            5,201
# 11     北安里            2,843
# 12     正守里            3,239
# 13     正得里            3,745
# 14     正義里            5,335
# 15     民安里            4,815
# 16     永安里           10,028
# 17     成功里            7,060
# 18     朱崙里            2,983
# 19     朱園里            4,602
# 20     朱馥里            6,235
# 21     江山里            7,786
# 22     江寧里            7,055
# 23     行仁里            8,468
# 24     行孝里            4,218
# 25     行政里            7,695
# 26     松江里            6,879
# 27     金泰里            7,709
# 28     恆安里            4,678
# 29     埤頭里            3,607
# 30     康樂里            2,668
# 31     復華里            4,833
# 32     晴光里            5,351
# 33     集英里            7,385
# ...

# %%
dfs_101 = tabula.read_pdf("101-104人口.pdf", pages=100)
df_101 = dfs_101[0]
df_101 = df_101.rename(columns={"Unnamed: 0":"village", "Unnamed: 1":"戶數", "Unnamed: 2":"total pepple_101", "口":"男性人口", "Unnamed: 3":"女性人口"})
df_101 = df_101.drop(["人", "數", "男性人口", "女性人口", "戶數"], axis=1)
df_101 = df_101.drop([0, 1], axis=0)
df_101
# Out:
#    village total pepple_101
# 2      力行里            5,897
# 3      下埤里            7,799
# 4      大佳里            1,143
# 5      大直里           10,340
# 6      中山里            6,142
# 7      中央里            3,872
# 8      中吉里            5,797
# 9      中原里            5,089
# 10     中庄里            5,129
# 11     北安里            2,846
# 12     正守里            3,209
# 13     正得里            3,682
# 14     正義里            5,250
# 15     民安里            4,847
# 16     永安里            9,926
# 17     成功里            6,912
# 18     朱崙里            2,942
# 19     朱園里            4,531
# 20     朱馥里            6,261
# 21     江山里            7,743
# 22     江寧里            6,970
# 23     行仁里            8,402
# 24     行孝里            4,179
# 25     行政里            7,685
# 26     松江里            6,828
# 27     金泰里            7,619
# 28     恆安里            4,449
# 29     埤頭里            3,607
# 30     康樂里            2,575
# 31     復華里            4,806
# 32     晴光里            5,234
# 33     集英里            7,343
# ...

# %%
population_df = pd.read_csv("village.csv")
population_df
# Out:
#    village
# 0      民安里
# 1      康樂里
# 2      中山里
# 3      聚盛里
# 4      正守里
# 5      正義里
# 6      正得里
# 7      集英里
# 8      聚葉里
# 9      中吉里
# 10     中原里
# 11     興亞里
# 12     埤頭里
# 13     朱崙里
# 14     力行里
# 15     中央里
# 16     朱馥里
# 17     龍洲里
# 18     朱園里
# 19     新福里
# 20     松江里
# 21     行孝里
# 22     下埤里
# 23     江寧里
# 24     江山里
# 25     新生里
# 26     中庄里
# 27     行政里
# 28     行仁里
# 29     復華里
# 30     金泰里
# 31     北安里
# 32     恆安里
# 33     成功里
# 34     永安里
# 35     大佳里
# 36     新喜里
# 37     晴光里
# 38     圓山里
# 39     劍潭里
# 40     大直里
# 41     新庄里

# %%
population_df = pd.merge(population_df, df_101, on="village", how="left")
population_df
# Out:
#    village total pepple_101
# 0      民安里            4,847
# 1      康樂里            2,575
# 2      中山里            6,142
# 3      聚盛里            4,051
# 4      正守里            3,209
# 5      正義里            5,250
# 6      正得里            3,682
# 7      集英里            7,343
# 8      聚葉里            3,914
# 9      中吉里            5,797
# 10     中原里            5,089
# 11     興亞里            5,331
# 12     埤頭里            3,607
# 13     朱崙里            2,942
# 14     力行里            5,897
# 15     中央里            3,872
# 16     朱馥里            6,261
# 17     龍洲里            5,229
# 18     朱園里            4,531
# 19     新福里            5,196
# 20     松江里            6,828
# 21     行孝里            4,179
# 22     下埤里            7,799
# 23     江寧里            6,970
# 24     江山里            7,743
# 25     新生里            5,063
# 26     中庄里            5,129
# 27     行政里            7,685
# 28     行仁里            8,402
# 29     復華里            4,806
# 30     金泰里            7,619
# 31     北安里            2,846
# ...

# %%
population_df = pd.merge(population_df, df_102, on="village", how="left")
population_df = pd.merge(population_df, df_103, on="village", how="left")
population_df = pd.merge(population_df, df_104, on="village", how="left")
population_df = pd.merge(population_df, df_105, on="village", how="left")
population_df = pd.merge(population_df, df_106, on="village", how="left")
population_df = pd.merge(population_df, df_107, on="village", how="left")
population_df = pd.merge(population_df, df_108, on="village", how="left")
population_df
# Out:
#    village total pepple_101 total pepple_102 total pepple_103  \
# 0      民安里            4,847            4,815            4,841
# 1      康樂里            2,575            2,668            2,684
# 2      中山里            6,142            6,264            6,424
# 3      聚盛里            4,051            4,168            4,236
# 4      正守里            3,209            3,239            3,300
# 5      正義里            5,250            5,335            5,368
# 6      正得里            3,682            3,745            3,789
# 7      集英里            7,343            7,385            7,454
# 8      聚葉里            3,914            3,927            3,980
# 9      中吉里            5,797            5,846            5,831
# 10     中原里            5,089            5,097            5,128
# 11     興亞里            5,331            5,424            5,404
# 12     埤頭里            3,607            3,607            3,541
# 13     朱崙里            2,942            2,983            2,994
# ...

# %%
population_df = pd.read_csv("population.csv")
population_df
# Out:
#    village  total pepple_101  total pepple_102  total pepple_103  \
# 0      民安里              4847              4815              4841
# 1      康樂里              2575              2668              2684
# 2      中山里              6142              6264              6424
# 3      聚盛里              4051              4168              4236
# 4      正守里              3209              3239              3300
# 5      正義里              5250              5335              5368
# 6      正得里              3682              3745              3789
# 7      集英里              7343              7385              7454
# 8      聚葉里              3914              3927              3980
# 9      中吉里              5797              5846              5831
# 10     中原里              5089              5097              5128
# 11     興亞里              5331              5424              5404
# 12     埤頭里              3607              3607              3541
# ...

# %%
# for i in population_df["total pepple_108"]:
#     print(type(i))
